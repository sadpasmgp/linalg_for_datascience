# %% [markdown]
# If A,B and C are matrices,
#
# A+B = B+A (matrix addition is commutative)
#
# A+(B+C = (A+B)+C) (matrix addition is distributive)
#
# However Matrix multiplication is not commutative or distributive.
#
# Shifting a matrix away from degeneracy,
# A + λI = C
#
# Shifting inflates a matrix from being a degenerate plane towards a sphere.

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import randint

# %%
#Create 2 matrices A and B

A = randint(1,200,16).reshape(4,4)
B = randint(1,100,16).reshape(4,4)

# %%
A+B
# Out:
# array([[241, 209, 111, 206],
#        [161, 231, 124, 104],
#        [135, 163,  30, 147],
#        [122, 178, 179, 246]])

# %%
B+A
# Out:
# array([[241, 209, 111, 206],
#        [161, 231, 124, 104],
#        [135, 163,  30, 147],
#        [122, 178, 179, 246]])

# %%
A+B == B+A
# Out:
# array([[ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True]])

# %%
#let C be A-B
C = A-B

# %%
A+(B+C)
# Out:
# array([[316, 322, 130, 278],
#        [226, 278, 100,  48],
#        [116, 246,  36, 202],
#        [ 46, 182, 170, 330]])

# %%
(A+B)+C
# Out:
# array([[316, 322, 130, 278],
#        [226, 278, 100,  48],
#        [116, 246,  36, 202],
#        [ 46, 182, 170, 330]])

# %%
A+(B+C) == (A+B)+C
# Out:
# array([[ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True]])

# %%
# "shifting" a matrix

l = .3 # lambda

N = 5  # size of square matrix

D = np.random.randn(N,N) # can only shift a square matrix
print(D)
print()
Ds = D + l*np.eye(N)
print(Ds)
# Out:
# [[ 0.47488636  0.95578458 -1.11360067  0.70102089  0.17764843]
#  [ 0.84113275  0.39969193  1.1477396   0.29643901 -1.13621193]
#  [ 0.32546175 -1.35337741  1.62738366  1.77015422  0.99560737]
#  [-0.92966293  0.2789797  -0.77256616  0.73951443  0.79516863]
#  [-0.39685985 -0.76040078  0.36949095  0.04502936  1.07163146]]
#
# [[ 0.77488636  0.95578458 -1.11360067  0.70102089  0.17764843]
#  [ 0.84113275  0.69969193  1.1477396   0.29643901 -1.13621193]
#  [ 0.32546175 -1.35337741  1.92738366  1.77015422  0.99560737]
#  [-0.92966293  0.2789797  -0.77256616  1.03951443  0.79516863]
#  [-0.39685985 -0.76040078  0.36949095  0.04502936  1.37163146]]

# %% [markdown]
# As we can see other than diagonal elements, all other elements are same

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(D)

# %%
plt.plot(Ds)
